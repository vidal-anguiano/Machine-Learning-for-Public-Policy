# %%
import sqlite3
from sodapy import Socrata

# %%
sqlite_file = 'db.db'

# %%
client = Socrata("data.cityofchicago.org",None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
client.get('cdmx-wzbz',limit=10)
# Out:
# [{'community_area': '66',
#   'completion_date': '2017-08-07T00:00:00.000',
#   'creation_date': '2017-08-07T00:00:00.000',
#   'latitude': '41.76386983154277',
#   'location': {'type': 'Point',
#    'coordinates': [-87.686745609992, 41.763869831543]},
#   'longitude': '-87.68674560999156',
#   'police_district': '8',
#   'service_request_number': '17-05251065',
#   'ssa': '14',
#   'status': 'Completed',
#   'street_address': '7125 S MAPLEWOOD AVE',
#   'type_of_service_request': 'Graffiti Removal',
#   'ward': '18',
#   'what_type_of_surface_is_the_graffiti_on_': 'Metal - Painted',
#   'where_is_the_graffiti_located_': 'Door',
#   'x_coordinate': '1160606.3195708',
#   'y_coordinate': '1857319.79946719',
#   'zip_code': '60629'},
#  {'community_area': '4',
#   'completion_date': '2017-08-07T00:00:00.000',
#   'creation_date': '2017-08-05T00:00:00.000',
#   'latitude': '41.96162484771538',
#   'location': {'type': 'Point',
#    'coordinates': [-87.689769617066, 41.961624847715]},
# ...
